# %%
path_to_folder='PATH_TO_FOLDER_HERE'

from google.colab import drive
import os

drive.mount('/content/drive')
os.chdir(path_to_folder)

# %%
# !pip install -r requirements_web_app.txt
# !pip install -r requirements_llm.txt

# !curl -fsSL https://packages.redis.io/redis-stack/redis-stack-server-6.2.6-v7.focal.x86_64.tar.gz -o redis-stack-server.tar.gz
# !tar -xvf redis-stack-server.tar.gz
# !pip install -q redis

# !wget http://archive.ubuntu.com/ubuntu/pool/main/o/openssl/libssl1.1_1.1.1f-1ubuntu2_amd64.deb
# !sudo dpkg -i libssl1.1_1.1.1f-1ubuntu2_amd64.deb

# %%
import redis

def initiate_redis():
  # !./redis-stack-server-6.2.6-v7/bin/redis-stack-server --daemonize yes

# %%
def worker():
  # !celery -A app.celery worker -P solo -l info

# %%
def flask_app():
  # !python app.py 1

# %%
import threading
import time

if __name__ == "__main__":

  t_initiate_redis = threading.Thread(target=initiate_redis)
  t_initiate_redis.start()
  time.sleep(5)

  t_worker = threading.Thread(target=worker)
  t_worker.start()
  time.sleep(25)

  t_flask_app = threading.Thread(target=flask_app)
  t_flask_app.start()

  t_worker.join()
  t_flask_app.join()
  t_initiate_redis.join()
